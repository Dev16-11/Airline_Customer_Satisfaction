# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Load the Dataset

# %%
df=pd.read_csv("/content/ML Project - Decision Tree Airline Customer Satisfaction U16955468980.txt")

# %%
df
# Out:
#       Unnamed: 0.1  Unnamed: 0      id  Gender      Customer Type  Age  \
# 0                0           0   70172    Male     Loyal Customer   13
# 1                1           1    5047    Male  disloyal Customer   25
# 2                2           2  110028  Female     Loyal Customer   26
# 3                3           3   24026  Female     Loyal Customer   25
# 4                4           4  119299    Male     Loyal Customer   61
# ...            ...         ...     ...     ...                ...  ...
# 9995          9995        9995  124365    Male     Loyal Customer   50
# 9996          9996        9996   22044    Male     Loyal Customer   38
# 9997          9997        9997   14057  Female     Loyal Customer   39
# 9998          9998        9998  113848    Male     Loyal Customer   52
# 9999          9999        9999    1865  Female     Loyal Customer   41
#
#        Type of Travel     Class  Flight Distance  Inflight wifi service  ...  \
# 0     Personal Travel  Eco Plus              460                      3  ...
# 1     Business travel  Business              235                      3  ...
# 2     Business travel  Business             1142                      2  ...
# 3     Business travel  Business              562                      2  ...
# 4     Business travel  Business              214                      3  ...
# ...               ...       ...              ...                    ...  ...
# 9995  Business travel  Business             3599                      3  ...
# 9996  Business travel  Business             3873                      5  ...
# 9997  Business travel  Business              319                      4  ...
# 9998  Business travel  Business             1363                      5  ...
# 9999  Business travel  Business             3938                      4  ...
#
#       Inflight entertainment  On-board service  Leg room service  \
# 0                          5                 4                 3
# 1                          1                 1                 5
# 2                          5                 4                 3
# 3                          2                 2                 5
# 4                          3                 3                 4
# ...                      ...               ...               ...
# 9995                       5                 5                 5
# 9996                       4                 4                 4
# 9997                       4                 4                 4
# 9998                       4                 4                 3
# 9999                       5                 5                 4
#
#       Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                    4                4                 5            5
# 1                    3                1                 4            1
# 2                    4                4                 4            5
# 3                    3                1                 4            2
# 4                    4                3                 3            3
# ...                ...              ...               ...          ...
# 9995                 5                5                 5            4
# 9996                 4                3                 4            5
# 9997                 4                3                 4            2
# 9998                 4                5                 4            5
# 9999                 5                5                 5            4
#
#       Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0                             25                      18.0
# 1                              1                       6.0
# 2                              0                       0.0
# 3                             11                       9.0
# 4                              0                       0.0
# ...                          ...                       ...
# 9995                          12                      24.0
# 9996                           0                       0.0
# 9997                           0                       0.0
# 9998                           1                      11.0
# 9999                           0                       0.0
#
#                  satisfaction
# 0     neutral or dissatisfied
# 1     neutral or dissatisfied
# 2                   satisfied
# 3     neutral or dissatisfied
# 4                   satisfied
# ...                       ...
# 9995                satisfied
# 9996                satisfied
# 9997                satisfied
# 9998                satisfied
# 9999                satisfied
#
# [10000 rows x 26 columns]

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0      id  Gender      Customer Type  Age  \
# 0             0           0   70172    Male     Loyal Customer   13
# 1             1           1    5047    Male  disloyal Customer   25
# 2             2           2  110028  Female     Loyal Customer   26
# 3             3           3   24026  Female     Loyal Customer   25
# 4             4           4  119299    Male     Loyal Customer   61
#
#     Type of Travel     Class  Flight Distance  Inflight wifi service  ...  \
# 0  Personal Travel  Eco Plus              460                      3  ...
# 1  Business travel  Business              235                      3  ...
# 2  Business travel  Business             1142                      2  ...
# 3  Business travel  Business              562                      2  ...
# 4  Business travel  Business              214                      3  ...
#
#    Inflight entertainment  On-board service  Leg room service  \
# 0                       5                 4                 3
# 1                       1                 1                 5
# 2                       5                 4                 3
# 3                       2                 2                 5
# 4                       3                 3                 4
#
#    Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                 4                4                 5            5
# 1                 3                1                 4            1
# 2                 4                4                 4            5
# 3                 3                1                 4            2
# 4                 4                3                 3            3
#
#    Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0                          25                      18.0
# 1                           1                       6.0
# 2                           0                       0.0
# 3                          11                       9.0
# 4                           0                       0.0
#
#               satisfaction
# 0  neutral or dissatisfied
# 1  neutral or dissatisfied
# 2                satisfied
# 3  neutral or dissatisfied
# 4                satisfied
#
# [5 rows x 26 columns]

# %%
df.tail()
# Out:
#       Unnamed: 0.1  Unnamed: 0      id  Gender   Customer Type  Age  \
# 9995          9995        9995  124365    Male  Loyal Customer   50
# 9996          9996        9996   22044    Male  Loyal Customer   38
# 9997          9997        9997   14057  Female  Loyal Customer   39
# 9998          9998        9998  113848    Male  Loyal Customer   52
# 9999          9999        9999    1865  Female  Loyal Customer   41
#
#        Type of Travel     Class  Flight Distance  Inflight wifi service  ...  \
# 9995  Business travel  Business             3599                      3  ...
# 9996  Business travel  Business             3873                      5  ...
# 9997  Business travel  Business              319                      4  ...
# 9998  Business travel  Business             1363                      5  ...
# 9999  Business travel  Business             3938                      4  ...
#
#       Inflight entertainment  On-board service  Leg room service  \
# 9995                       5                 5                 5
# 9996                       4                 4                 4
# 9997                       4                 4                 4
# 9998                       4                 4                 3
# 9999                       5                 5                 4
#
#       Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 9995                 5                5                 5            4
# 9996                 4                3                 4            5
# 9997                 4                3                 4            2
# 9998                 4                5                 4            5
# 9999                 5                5                 5            4
#
#       Departure Delay in Minutes  Arrival Delay in Minutes  satisfaction
# 9995                          12                      24.0     satisfied
# 9996                           0                       0.0     satisfied
# 9997                           0                       0.0     satisfied
# 9998                           1                      11.0     satisfied
# 9999                           0                       0.0     satisfied
#
# [5 rows x 26 columns]

# %%
df.sample(5)
# Out:
#       Unnamed: 0.1  Unnamed: 0      id  Gender      Customer Type  Age  \
# 4043          4043        4043   80379  Female  disloyal Customer   20
# 1716          1716        1716  127983    Male  disloyal Customer   63
# 3671          3671        3671  111389    Male     Loyal Customer   28
# 8219          8219        8219  118384  Female     Loyal Customer   28
# 4068          4068        4068   38440  Female     Loyal Customer   40
#
#        Type of Travel     Class  Flight Distance  Inflight wifi service  ...  \
# 4043  Business travel       Eco              368                      2  ...
# 1716  Business travel       Eco              749                      3  ...
# 3671  Personal Travel       Eco             1173                      1  ...
# 8219  Business travel  Business             2285                      5  ...
# 4068  Business travel  Business              588                      4  ...
#
#       Inflight entertainment  On-board service  Leg room service  \
# 4043                       1                 3                 3
# 1716                       1                 2                 2
# 3671                       2                 1                 2
# 8219                       5                 4                 3
# 4068                       4                 4                 4
#
#       Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 4043                 2                4                 3            1
# 1716                 4                2                 4            1
# 3671                 1                4                 2            2
# 8219                 5                4                 5            5
# 4068                 4                5                 4            5
#
#       Departure Delay in Minutes  Arrival Delay in Minutes  \
# 4043                          24                      10.0
# 1716                           0                      17.0
# 3671                           0                       0.0
# 8219                           0                       0.0
# 4068                          10                      15.0
#
#                  satisfaction
# 4043  neutral or dissatisfied
# 1716  neutral or dissatisfied
# 3671  neutral or dissatisfied
# 8219                satisfied
# 4068                satisfied
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 26 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0.1                       10000 non-null  int64
#  1   Unnamed: 0                         10000 non-null  int64
#  2   id                                 10000 non-null  int64
#  3   Gender                             10000 non-null  object
#  4   Customer Type                      10000 non-null  object
#  5   Age                                10000 non-null  int64
#  6   Type of Travel                     10000 non-null  object
#  7   Class                              10000 non-null  object
#  8   Flight Distance                    10000 non-null  int64
#  9   Inflight wifi service              10000 non-null  int64
#  10  Departure/Arrival time convenient  10000 non-null  int64
#  11  Ease of Online booking             10000 non-null  int64
#  12  Gate location                      10000 non-null  int64
#  13  Food and drink                     10000 non-null  int64
#  14  Online boarding                    10000 non-null  int64
#  15  Seat comfort                       10000 non-null  int64
#  16  Inflight entertainment             10000 non-null  int64
#  17  On-board service                   10000 non-null  int64
#  18  Leg room service                   10000 non-null  int64
#  19  Baggage handling                   10000 non-null  int64
#  20  Checkin service                    10000 non-null  int64
#  21  Inflight service                   10000 non-null  int64
#  22  Cleanliness                        10000 non-null  int64
#  23  Departure Delay in Minutes         10000 non-null  int64
#  24  Arrival Delay in Minutes           9974 non-null   float64
#  25  satisfaction                       10000 non-null  object
# dtypes: float64(1), int64(20), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# Data Columns

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age',
#        'Type of Travel', 'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %% [markdown]
# Data Description

# %%
df.describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0             id           Age  \
# count   10000.00000  10000.00000   10000.000000  10000.000000
# mean     4999.50000   4999.50000   64950.978500     39.303700
# std      2886.89568   2886.89568   37420.905082     15.116478
# min         0.00000      0.00000       8.000000      7.000000
# 25%      2499.75000   2499.75000   32330.500000     27.000000
# 50%      4999.50000   4999.50000   64941.000000     40.000000
# 75%      7499.25000   7499.25000   97579.750000     51.000000
# max      9999.00000   9999.00000  129863.000000     85.000000
#
#        Flight Distance  Inflight wifi service  \
# count     10000.000000           10000.000000
# mean       1198.823800               2.731500
# std        1001.774138               1.328226
# min          31.000000               0.000000
# 25%         413.000000               2.000000
# 50%         852.500000               3.000000
# 75%        1747.000000               4.000000
# max        4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                       10000.000000            10000.000000
# mean                            3.038900                2.753600
# std                             1.528077                1.403241
# min                             0.000000                0.000000
# 25%                             2.000000                2.000000
# 50%                             3.000000                3.000000
# 75%                             4.000000                4.000000
# max                             5.000000                5.000000
#
#        Gate location  Food and drink  ...  Seat comfort  \
# count    10000.00000    10000.000000  ...  10000.000000
# mean         2.96890        3.208800  ...      3.411300
# std          1.28425        1.339769  ...      1.326012
# min          1.00000        0.000000  ...      0.000000
# 25%          2.00000        2.000000  ...      2.000000
# 50%          3.00000        3.000000  ...      4.000000
# 75%          4.00000        4.000000  ...      4.000000
# max          5.00000        5.000000  ...      5.000000
#
#        Inflight entertainment  On-board service  Leg room service  \
# count            10000.000000      10000.000000      10000.000000
# mean                 3.335500          3.366000          3.346500
# std                  1.340567          1.288336          1.311415
# min                  0.000000          0.000000          0.000000
# 25%                  2.000000          2.000000          2.000000
# 50%                  4.000000          4.000000          4.000000
# 75%                  4.000000          4.000000          4.000000
# max                  5.000000          5.000000          5.000000
#
#        Baggage handling  Checkin service  Inflight service   Cleanliness  \
# count      10000.000000     10000.000000      10000.000000  10000.000000
# mean           3.619900         3.285600          3.627400      3.268200
# std            1.190028         1.269013          1.181401      1.321077
# min            1.000000         0.000000          0.000000      0.000000
# 25%            3.000000         2.000000          3.000000      2.000000
# 50%            4.000000         3.000000          4.000000      3.000000
# 75%            5.000000         4.000000          5.000000      4.000000
# max            5.000000         5.000000          5.000000      5.000000
#
#        Departure Delay in Minutes  Arrival Delay in Minutes
# count                10000.000000               9974.000000
# mean                    14.785400                 15.242130
# std                     38.217509                 38.810195
# min                      0.000000                  0.000000
# 25%                      0.000000                  0.000000
# 50%                      0.000000                  0.000000
# 75%                     13.000000                 13.000000
# max                   1305.000000               1280.000000
#
# [8 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1                          0
# Unnamed: 0                            0
# id                                    0
# Gender                                0
# Customer Type                         0
# Age                                   0
# Type of Travel                        0
# Class                                 0
# Flight Distance                       0
# Inflight wifi service                 0
# Departure/Arrival time convenient     0
# Ease of Online booking                0
# Gate location                         0
# Food and drink                        0
# Online boarding                       0
# Seat comfort                          0
# Inflight entertainment                0
# On-board service                      0
# Leg room service                      0
# Baggage handling                      0
# Checkin service                       0
# Inflight service                      0
# Cleanliness                           0
# Departure Delay in Minutes            0
# Arrival Delay in Minutes             26
# satisfaction                          0
# dtype: int64

# %% [markdown]
# Dropping 'Unnamed: 0.1', 'Unnamed: 0' column

# %%
df=df.drop(['Unnamed: 0.1', 'Unnamed: 0'],axis=1)

# %%
df
# Out:
#           id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0      70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1       5047    Male  disloyal Customer   25  Business travel  Business
# 2     110028  Female     Loyal Customer   26  Business travel  Business
# 3      24026  Female     Loyal Customer   25  Business travel  Business
# 4     119299    Male     Loyal Customer   61  Business travel  Business
# ...      ...     ...                ...  ...              ...       ...
# 9995  124365    Male     Loyal Customer   50  Business travel  Business
# 9996   22044    Male     Loyal Customer   38  Business travel  Business
# 9997   14057  Female     Loyal Customer   39  Business travel  Business
# 9998  113848    Male     Loyal Customer   52  Business travel  Business
# 9999    1865  Female     Loyal Customer   41  Business travel  Business
#
#       Flight Distance  Inflight wifi service  \
# 0                 460                      3
# 1                 235                      3
# 2                1142                      2
# 3                 562                      2
# 4                 214                      3
# ...               ...                    ...
# 9995             3599                      3
# 9996             3873                      5
# 9997              319                      4
# 9998             1363                      5
# 9999             3938                      4
#
#       Departure/Arrival time convenient  Ease of Online booking  ...  \
# 0                                     4                       3  ...
# 1                                     2                       3  ...
# 2                                     2                       2  ...
# 3                                     5                       5  ...
# 4                                     3                       3  ...
# ...                                 ...                     ...  ...
# 9995                                  3                       3  ...
# 9996                                  5                       5  ...
# 9997                                  4                       4  ...
# 9998                                  5                       5  ...
# 9999                                  4                       4  ...
#
#       Inflight entertainment  On-board service  Leg room service  \
# 0                          5                 4                 3
# 1                          1                 1                 5
# 2                          5                 4                 3
# 3                          2                 2                 5
# 4                          3                 3                 4
# ...                      ...               ...               ...
# 9995                       5                 5                 5
# 9996                       4                 4                 4
# 9997                       4                 4                 4
# 9998                       4                 4                 3
# 9999                       5                 5                 4
#
#       Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                    4                4                 5            5
# 1                    3                1                 4            1
# 2                    4                4                 4            5
# 3                    3                1                 4            2
# 4                    4                3                 3            3
# ...                ...              ...               ...          ...
# 9995                 5                5                 5            4
# 9996                 4                3                 4            5
# 9997                 4                3                 4            2
# 9998                 4                5                 4            5
# 9999                 5                5                 5            4
#
#       Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0                             25                      18.0
# 1                              1                       6.0
# 2                              0                       0.0
# 3                             11                       9.0
# 4                              0                       0.0
# ...                          ...                       ...
# 9995                          12                      24.0
# 9996                           0                       0.0
# 9997                           0                       0.0
# 9998                           1                      11.0
# 9999                           0                       0.0
#
#                  satisfaction
# 0     neutral or dissatisfied
# 1     neutral or dissatisfied
# 2                   satisfied
# 3     neutral or dissatisfied
# 4                   satisfied
# ...                       ...
# 9995                satisfied
# 9996                satisfied
# 9997                satisfied
# 9998                satisfied
# 9999                satisfied
#
# [10000 rows x 24 columns]

# %%
df.columns=[each.replace(" ","_") for each in df.columns]

# %% [markdown]
# Replacing " " with "_" in columns

# %%
df.columns
# Out:
# Index(['id', 'Gender', 'Customer_Type', 'Age', 'Type_of_Travel', 'Class',
#        'Flight_Distance', 'Inflight_wifi_service',
#        'Departure/Arrival_time_convenient', 'Ease_of_Online_booking',
#        'Gate_location', 'Food_and_drink', 'Online_boarding', 'Seat_comfort',
#        'Inflight_entertainment', 'On-board_service', 'Leg_room_service',
#        'Baggage_handling', 'Checkin_service', 'Inflight_service',
#        'Cleanliness', 'Departure_Delay_in_Minutes', 'Arrival_Delay_in_Minutes',
#        'satisfaction'],
#       dtype='object')

# %% [markdown]
# Giving Label to satisfaction column

# %%
df["satisfaction"]
# Out:
# 0       neutral or dissatisfied
# 1       neutral or dissatisfied
# 2                     satisfied
# 3       neutral or dissatisfied
# 4                     satisfied
#                  ...
# 9995                  satisfied
# 9996                  satisfied
# 9997                  satisfied
# 9998                  satisfied
# 9999                  satisfied
# Name: satisfaction, Length: 10000, dtype: object

# %%
df["satisfaction"]=[1 if each=="satisfied" else 0 for each in df.satisfaction]

# %%
df["satisfaction"]
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 9995    1
# 9996    1
# 9997    1
# 9998    1
# 9999    1
# Name: satisfaction, Length: 10000, dtype: int64

# %%
df["satisfaction"].value_counts()
# Out:
# satisfaction
# 0    5689
# 1    4311
# Name: count, dtype: int64

# %%
df["satisfaction"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='satisfaction'>

# %%
df["Gender"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Gender'>

# %% [markdown]
# Getting the mean value for gender and satisfaction column

# %%
df[["Gender","satisfaction"]].groupby(["Gender"],as_index=False).mean().sort_values(by="satisfaction",ascending=False)
# Out:
#    Gender  satisfaction
# 1    Male      0.438062
# 0  Female      0.424432

# %% [markdown]
# Getting the mean value for age and satisfaction column

# %%
df[["Age","satisfaction"]].groupby(["Age"],as_index=False).mean().sort_values(by="satisfaction",ascending=False)
# Out:
#     Age  satisfaction
# 71   79      0.666667
# 39   46      0.643192
# 34   41      0.632743
# 38   45      0.608466
# 66   73      0.600000
# ..  ...           ...
# 7    14      0.076923
# 0     7      0.071429
# 59   66      0.050000
# 69   76      0.000000
# 73   85      0.000000
#
# [74 rows x 2 columns]

# %% [markdown]
# Getting the mean value for Food and Drink and satisfaction column

# %%
df[["Food_and_drink","satisfaction"]].groupby(["Food_and_drink"],as_index=False).mean().sort_values(by="satisfaction",ascending=False)
# Out:
#    Food_and_drink  satisfaction
# 0               0      0.625000
# 5               5      0.566176
# 4               4      0.515050
# 3               3      0.404990
# 2               2      0.362305
# 1               1      0.198142

# %% [markdown]
# Display a boxplot for flight distances

# %%
df["Flight_Distance"].plot(kind="box")
# Out:
# <Axes: >

# %% [markdown]
# Display a boxplot for checkin service

# %%
df["Checkin_service"].plot(kind="box")
# Out:
# <Axes: >

# %% [markdown]
# Fing all the Null values

# %%
df.isnull().sum()
# Out:
# id                                    0
# Gender                                0
# Customer_Type                         0
# Age                                   0
# Type_of_Travel                        0
# Class                                 0
# Flight_Distance                       0
# Inflight_wifi_service                 0
# Departure/Arrival_time_convenient     0
# Ease_of_Online_booking                0
# Gate_location                         0
# Food_and_drink                        0
# Online_boarding                       0
# Seat_comfort                          0
# Inflight_entertainment                0
# On-board_service                      0
# Leg_room_service                      0
# Baggage_handling                      0
# Checkin_service                       0
# Inflight_service                      0
# Cleanliness                           0
# Departure_Delay_in_Minutes            0
# Arrival_Delay_in_Minutes             26
# satisfaction                          0
# dtype: int64

# %% [markdown]
# Drop all the null values

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# id                                   0
# Gender                               0
# Customer_Type                        0
# Age                                  0
# Type_of_Travel                       0
# Class                                0
# Flight_Distance                      0
# Inflight_wifi_service                0
# Departure/Arrival_time_convenient    0
# Ease_of_Online_booking               0
# Gate_location                        0
# Food_and_drink                       0
# Online_boarding                      0
# Seat_comfort                         0
# Inflight_entertainment               0
# On-board_service                     0
# Leg_room_service                     0
# Baggage_handling                     0
# Checkin_service                      0
# Inflight_service                     0
# Cleanliness                          0
# Departure_Delay_in_Minutes           0
# Arrival_Delay_in_Minutes             0
# satisfaction                         0
# dtype: int64

# %% [markdown]
# Finding Unique Flight distance

# %%
df["Flight_Distance"].unique()
# Out:
# array([ 460,  235, 1142, ..., 3033, 1319, 1443])

# %% [markdown]
# ## Encoding in columns Gender, Customer_Type, Type_of_Travel, and Class.

# %%
from sklearn.preprocessing import LabelEncoder
enc=LabelEncoder()

# %%
df["Gender"]=enc.fit_transform(df["Gender"])
df["Customer_Type"]=enc.fit_transform(df["Customer_Type"])
df["Type_of_Travel"]=enc.fit_transform(df["Type_of_Travel"])
df["Class"]=enc.fit_transform(df["Class"])

# %%
df.columns
# Out:
# Index(['id', 'Gender', 'Customer_Type', 'Age', 'Type_of_Travel', 'Class',
#        'Flight_Distance', 'Inflight_wifi_service',
#        'Departure/Arrival_time_convenient', 'Ease_of_Online_booking',
#        'Gate_location', 'Food_and_drink', 'Online_boarding', 'Seat_comfort',
#        'Inflight_entertainment', 'On-board_service', 'Leg_room_service',
#        'Baggage_handling', 'Checkin_service', 'Inflight_service',
#        'Cleanliness', 'Departure_Delay_in_Minutes', 'Arrival_Delay_in_Minutes',
#        'satisfaction'],
#       dtype='object')

# %% [markdown]
# ## Dropping Column id

# %%
df=df.drop("id",axis=1)

# %%
df
# Out:
#       Gender  Customer_Type  Age  Type_of_Travel  Class  Flight_Distance  \
# 0          1              0   13               1      2              460
# 1          1              1   25               0      0              235
# 2          0              0   26               0      0             1142
# 3          0              0   25               0      0              562
# 4          1              0   61               0      0              214
# ...      ...            ...  ...             ...    ...              ...
# 9995       1              0   50               0      0             3599
# 9996       1              0   38               0      0             3873
# 9997       0              0   39               0      0              319
# 9998       1              0   52               0      0             1363
# 9999       0              0   41               0      0             3938
#
#       Inflight_wifi_service  Departure/Arrival_time_convenient  \
# 0                         3                                  4
# 1                         3                                  2
# 2                         2                                  2
# 3                         2                                  5
# 4                         3                                  3
# ...                     ...                                ...
# 9995                      3                                  3
# 9996                      5                                  5
# 9997                      4                                  4
# 9998                      5                                  5
# 9999                      4                                  4
#
#       Ease_of_Online_booking  Gate_location  ...  Inflight_entertainment  \
# 0                          3              1  ...                       5
# 1                          3              3  ...                       1
# 2                          2              2  ...                       5
# 3                          5              5  ...                       2
# 4                          3              3  ...                       3
# ...                      ...            ...  ...                     ...
# 9995                       3              3  ...                       5
# 9996                       5              5  ...                       4
# 9997                       4              4  ...                       4
# 9998                       5              5  ...                       4
# 9999                       4              4  ...                       5
#
#       On-board_service  Leg_room_service  Baggage_handling  Checkin_service  \
# 0                    4                 3                 4                4
# 1                    1                 5                 3                1
# 2                    4                 3                 4                4
# 3                    2                 5                 3                1
# 4                    3                 4                 4                3
# ...                ...               ...               ...              ...
# 9995                 5                 5                 5                5
# 9996                 4                 4                 4                3
# 9997                 4                 4                 4                3
# 9998                 4                 3                 4                5
# 9999                 5                 4                 5                5
#
#       Inflight_service  Cleanliness  Departure_Delay_in_Minutes  \
# 0                    5            5                          25
# 1                    4            1                           1
# 2                    4            5                           0
# 3                    4            2                          11
# 4                    3            3                           0
# ...                ...          ...                         ...
# 9995                 5            4                          12
# 9996                 4            5                           0
# 9997                 4            2                           0
# 9998                 4            5                           1
# 9999                 5            4                           0
#
#       Arrival_Delay_in_Minutes  satisfaction
# 0                         18.0             0
# 1                          6.0             0
# 2                          0.0             1
# 3                          9.0             0
# 4                          0.0             1
# ...                        ...           ...
# 9995                      24.0             1
# 9996                       0.0             1
# 9997                       0.0             1
# 9998                      11.0             1
# 9999                       0.0             1
#
# [9974 rows x 23 columns]

# %% [markdown]
# ## Creating Feature and Target data

# %%
x=df.drop("satisfaction",axis=1)
y=df["satisfaction"]

# %%
x.shape
# Out:
# (9974, 22)

# %%
y.shape
# Out:
# (9974,)

# %% [markdown]
# ## Scalling the Feature data

# %%
x
# Out:
#       Gender  Customer_Type  Age  Type_of_Travel  Class  Flight_Distance  \
# 0          1              0   13               1      2              460
# 1          1              1   25               0      0              235
# 2          0              0   26               0      0             1142
# 3          0              0   25               0      0              562
# 4          1              0   61               0      0              214
# ...      ...            ...  ...             ...    ...              ...
# 9995       1              0   50               0      0             3599
# 9996       1              0   38               0      0             3873
# 9997       0              0   39               0      0              319
# 9998       1              0   52               0      0             1363
# 9999       0              0   41               0      0             3938
#
#       Inflight_wifi_service  Departure/Arrival_time_convenient  \
# 0                         3                                  4
# 1                         3                                  2
# 2                         2                                  2
# 3                         2                                  5
# 4                         3                                  3
# ...                     ...                                ...
# 9995                      3                                  3
# 9996                      5                                  5
# 9997                      4                                  4
# 9998                      5                                  5
# 9999                      4                                  4
#
#       Ease_of_Online_booking  Gate_location  ...  Seat_comfort  \
# 0                          3              1  ...             5
# 1                          3              3  ...             1
# 2                          2              2  ...             5
# 3                          5              5  ...             2
# 4                          3              3  ...             5
# ...                      ...            ...  ...           ...
# 9995                       3              3  ...             4
# 9996                       5              5  ...             5
# 9997                       4              4  ...             4
# 9998                       5              5  ...             5
# 9999                       4              4  ...             5
#
#       Inflight_entertainment  On-board_service  Leg_room_service  \
# 0                          5                 4                 3
# 1                          1                 1                 5
# 2                          5                 4                 3
# 3                          2                 2                 5
# 4                          3                 3                 4
# ...                      ...               ...               ...
# 9995                       5                 5                 5
# 9996                       4                 4                 4
# 9997                       4                 4                 4
# 9998                       4                 4                 3
# 9999                       5                 5                 4
#
#       Baggage_handling  Checkin_service  Inflight_service  Cleanliness  \
# 0                    4                4                 5            5
# 1                    3                1                 4            1
# 2                    4                4                 4            5
# 3                    3                1                 4            2
# 4                    4                3                 3            3
# ...                ...              ...               ...          ...
# 9995                 5                5                 5            4
# 9996                 4                3                 4            5
# 9997                 4                3                 4            2
# 9998                 4                5                 4            5
# 9999                 5                5                 5            4
#
#       Departure_Delay_in_Minutes  Arrival_Delay_in_Minutes
# 0                             25                      18.0
# 1                              1                       6.0
# 2                              0                       0.0
# 3                             11                       9.0
# 4                              0                       0.0
# ...                          ...                       ...
# 9995                          12                      24.0
# 9996                           0                       0.0
# 9997                           0                       0.0
# 9998                           1                      11.0
# 9999                           0                       0.0
#
# [9974 rows x 22 columns]

# %%
cols=x.columns

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
x=sc.fit_transform(x)

# %%
x
# Out:
# array([[ 1.022101  , -0.46815207, -1.7390128 , ...,  1.31151575,
#          0.2672691 ,  0.07106403],
#        [ 1.022101  ,  2.13605805, -0.9454767 , ..., -1.71598135,
#         -0.3602227 , -0.23814858],
#        [-0.9783769 , -0.46815207, -0.87934869, ...,  1.31151575,
#         -0.38636819, -0.39275488],
#        ...,
#        [-0.9783769 , -0.46815207, -0.01968459, ..., -0.95910708,
#         -0.38636819, -0.39275488],
#        [ 1.022101  , -0.46815207,  0.83997952, ...,  1.31151575,
#         -0.3602227 , -0.10930999],
#        [-0.9783769 , -0.46815207,  0.11257143, ...,  0.55464148,
#         -0.38636819, -0.39275488]])

# %%
x=pd.DataFrame(x,columns=cols)

# %%
x
# Out:
#         Gender  Customer_Type       Age  Type_of_Travel     Class  \
# 0     1.022101      -0.468152 -1.739013        1.507418  2.269235
# 1     1.022101       2.136058 -0.945477       -0.663386 -0.947100
# 2    -0.978377      -0.468152 -0.879349       -0.663386 -0.947100
# 3    -0.978377      -0.468152 -0.945477       -0.663386 -0.947100
# 4     1.022101      -0.468152  1.435132       -0.663386 -0.947100
# ...        ...            ...       ...             ...       ...
# 9969  1.022101      -0.468152  0.707724       -0.663386 -0.947100
# 9970  1.022101      -0.468152 -0.085813       -0.663386 -0.947100
# 9971 -0.978377      -0.468152 -0.019685       -0.663386 -0.947100
# 9972  1.022101      -0.468152  0.839980       -0.663386 -0.947100
# 9973 -0.978377      -0.468152  0.112571       -0.663386 -0.947100
#
#       Flight_Distance  Inflight_wifi_service  \
# 0           -0.737519               0.201740
# 1           -0.962124               0.201740
# 2           -0.056715              -0.551311
# 3           -0.635698              -0.551311
# 4           -0.983087               0.201740
# ...               ...                    ...
# 9969         2.395974               0.201740
# 9970         2.669493               1.707841
# 9971        -0.878271               0.954790
# 9972         0.163897               1.707841
# 9973         2.734379               0.954790
#
#       Departure/Arrival_time_convenient  Ease_of_Online_booking  \
# 0                              0.629103                0.175328
# 1                             -0.680029                0.175328
# 2                             -0.680029               -0.537562
# 3                              1.283668                1.601106
# 4                             -0.025463                0.175328
# ...                                 ...                     ...
# 9969                          -0.025463                0.175328
# 9970                           1.283668                1.601106
# 9971                           0.629103                0.888217
# 9972                           1.283668                1.601106
# 9973                           0.629103                0.888217
#
#       Gate_location  ...  Seat_comfort  Inflight_entertainment  \
# 0         -1.534155  ...      1.197922                1.241813
# 1          0.023662  ...     -1.818316               -1.741829
# 2         -0.755246  ...      1.197922                1.241813
# 3          1.581480  ...     -1.064257               -0.995918
# 4          0.023662  ...      1.197922               -0.250008
# ...             ...  ...           ...                     ...
# 9969       0.023662  ...      0.443862                1.241813
# 9970       1.581480  ...      1.197922                0.495903
# 9971       0.802571  ...      0.443862                0.495903
# 9972       1.581480  ...      1.197922                0.495903
# 9973       0.802571  ...      1.197922                1.241813
#
#       On-board_service  Leg_room_service  Baggage_handling  Checkin_service  \
# 0             0.492014         -0.264779          0.319439         0.562836
# 1            -1.836318          1.260872         -0.520774        -1.801501
# 2             0.492014         -0.264779          0.319439         0.562836
# 3            -1.060207          1.260872         -0.520774        -1.801501
# 4            -0.284097          0.498047          0.319439        -0.225277
# ...                ...               ...               ...              ...
# 9969          1.268125          1.260872          1.159652         1.350948
# 9970          0.492014          0.498047          0.319439        -0.225277
# 9971          0.492014          0.498047          0.319439        -0.225277
# 9972          0.492014         -0.264779          0.319439         1.350948
# 9973          1.268125          0.498047          1.159652         1.350948
#
#       Inflight_service  Cleanliness  Departure_Delay_in_Minutes  \
# 0             1.161719     1.311516                    0.267269
# 1             0.315212    -1.715981                   -0.360223
# 2             0.315212     1.311516                   -0.386368
# 3             0.315212    -0.959107                   -0.098768
# 4            -0.531294    -0.202233                   -0.386368
# ...                ...          ...                         ...
# 9969          1.161719     0.554641                   -0.072622
# 9970          0.315212     1.311516                   -0.386368
# 9971          0.315212    -0.959107                   -0.386368
# 9972          0.315212     1.311516                   -0.360223
# 9973          1.161719     0.554641                   -0.386368
#
#       Arrival_Delay_in_Minutes
# 0                     0.071064
# 1                    -0.238149
# 2                    -0.392755
# 3                    -0.160845
# 4                    -0.392755
# ...                        ...
# 9969                  0.225670
# 9970                 -0.392755
# 9971                 -0.392755
# 9972                 -0.109310
# 9973                 -0.392755
#
# [9974 rows x 22 columns]

# %% [markdown]
# # Splitting Data In training & testing sets

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (7979, 22)

# %%
x_test.shape
# Out:
# (1995, 22)

# %%
y_train.shape
# Out:
# (7979,)

# %%
y_test.shape
# Out:
# (1995,)

# %% [markdown]
# ## Implementing Decision Tree with various parameters

# %%
from sklearn.tree import DecisionTreeClassifier
params_dt = {'max_depth': 12,
             'max_features': "sqrt",
            'min_samples_leaf':1,
             'min_samples_split':2,
            'criterion':'gini'}

model_dt = DecisionTreeClassifier(**params_dt)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,precision_score,recall_score

# %% [markdown]
# ## Creating a function to display precision score, recall score, accuracy, classification report, confusion matrix, F1 Score

# %%
def run_model(model_dt, x_train, y_train, x_test, y_test):
    model_dt.fit(x_train,y_train.ravel())
    y_pred = model_dt.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    print("pricison_score: ",precision_score(y_test, y_pred))
    print("recall_score: ",recall_score(y_test, y_pred))
    print("Accuracy = {}".format(accuracy))
    print(classification_report(y_test,y_pred,digits=5))
    print(confusion_matrix(y_test,y_pred))

# %%
run_model(model_dt,x_train, y_train, x_test, y_test)
# Out:
# pricison_score:  0.8915801614763552
# recall_score:  0.895712630359212
# Accuracy = 0.9077694235588972
#               precision    recall  f1-score   support
#
#            0    0.92021   0.91696   0.91858      1132
#            1    0.89158   0.89571   0.89364       863
#
#     accuracy                        0.90777      1995
#    macro avg    0.90590   0.90634   0.90611      1995
# weighted avg    0.90783   0.90777   0.90779      1995
#
# [[1038   94]
#  [  90  773]]
